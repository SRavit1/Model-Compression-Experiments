# %% [markdown]
# Adapted from https://www.tensorflow.org/tutorials/keras/overfit_and_underfit#strategies_to_prevent_overfitting
# #Goals
# - demonstrate the effects of Regular, L1, and Lasso Control with low-level control
# - visualize experiment results through TensorBoard

# %% [markdown]
# #Imports

# %%
import tensorflow as tf

from tensorflow.keras import layers
from tensorflow.keras import regularizers

# %%
# !pip install -q git+https://github.com/tensorflow/docs

import tensorflow_docs as tfdocs
import tensorflow_docs.modeling
import tensorflow_docs.plots
# Out:
#   Building wheel for tensorflow-docs (setup.py) ... done

# %%
from  IPython import display
from matplotlib import pyplot as plt

import numpy as np

import pathlib
import shutil
import tempfile
import gzip
import pandas as pd

# %%
logdir = pathlib.Path(tempfile.mkdtemp())/"tensorboard_logs"
shutil.rmtree(logdir, ignore_errors=True)

# %% [markdown]
# #Dataset Preprocessing

# %%
from tensorflow.keras.datasets import mnist

# %%
mnist_data = mnist.load_data()
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()

X_train = np.reshape(X_train, (60000, 28, 28, 1))
X_test = np.reshape (X_test, (10000, 28, 28, 1))

Y_train = np.eye(10)[Y_train]
Y_test = np.eye(10)[Y_test]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step

# %%
def display_image (image_matrix):
  plt.imshow(np.reshape(image_matrix[:][:], (28, 28)))
def display_label (label_onehot):
  print(np.where(label_onehot==1)[0].item(0))

print ("label: ", end="")
display_label(Y_train[2])
display_image(X_train[2])
# Out:
# label: 4

# %% [markdown]
# #Model Training Parameters

# %% [markdown]
# ##Learning Rate Scheduler

# %%
SIDE_LENGTH = 28
FEATURES = SIDE_LENGTH*SIDE_LENGTH

N_VALIDATION = int(1e3)
N_TRAIN = int(1e4)
BUFFER_SIZE = int(1e4)
BATCH_SIZE = 500
STEPS_PER_EPOCH = N_TRAIN//BATCH_SIZE

# %%
lr_schedule = tf.keras.optimizers.schedules.InverseTimeDecay(
  0.001,
  decay_steps=STEPS_PER_EPOCH*1000,
  decay_rate=1,
  staircase=False)

def get_optimizer():
  return tf.keras.optimizers.Adam(lr_schedule)

# %%
step = np.linspace(0,100000)
lr = lr_schedule(step)
plt.figure(figsize = (8,6))
plt.plot(step/STEPS_PER_EPOCH, lr)
plt.ylim([0,max(plt.ylim())])
plt.xlabel('Epoch')
_ = plt.ylabel('Learning Rate')

# %% [markdown]
# ##Training Callbacks

# %%
def get_callbacks(name):
  return [
    tfdocs.modeling.EpochDots(),
    tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=50),
    tf.keras.callbacks.TensorBoard(logdir/name),
  ]

# %% [markdown]
# ##Training Method

# %%
def compile_and_fit(model, name, optimizer=None, max_epochs=10000):
  if optimizer is None:
    optimizer = get_optimizer()
  model.compile(
      optimizer=optimizer,
      loss=tf.keras.losses.categorical_crossentropy,
      metrics=['accuracy']
  )

  model.summary()

  history = model.fit(
    X_train,
    Y_train,
    steps_per_epoch = STEPS_PER_EPOCH,
    epochs=max_epochs,
    validation_data=(X_test, Y_test),
    callbacks=get_callbacks(name),
    verbose=1
  )
  return history

# %% [markdown]
# #Training Models

# %%
histories = {}

# %%
def getModel(regularizer, name=None):
  initializer = tf.keras.initializers.GlorotNormal(seed = 0)
  return tf.keras.Sequential([
    layers.Conv2D(100, (11, 11), name='conv1', strides=(2,2), activation='relu', kernel_regularizer=regularizer, kernel_initializer=initializer, input_shape=(SIDE_LENGTH, SIDE_LENGTH, 1),),
    layers.Conv2D(100, (5, 5), name='conv2', activation='relu', kernel_regularizer=regularizer, kernel_initializer=initializer),
    layers.Flatten(),
    layers.Dense(10, activation='softmax', kernel_regularizer=regularizer, kernel_initializer=initializer)
  ], name=name)

# %% [markdown]
# ##Training Regular Model

# %%
regular_model_name = "regular"
regular_model = getModel(None, regular_model_name)
histories[regular_model_name] = compile_and_fit(regular_model, regular_model_name)
# Out:
# Model: "regular"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1 (Conv2D)               (None, 9, 9, 100)         12200
# _________________________________________________________________
# conv2 (Conv2D)               (None, 5, 5, 100)         250100
# _________________________________________________________________
# flatten (Flatten)            (None, 2500)              0
# _________________________________________________________________
# dense (Dense)                (None, 10)                25010
# =================================================================
# Total params: 287,310
# Trainable params: 287,310
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10000
#  1/20 [>.............................] - ETA: 0s - loss: 16.9025 - accuracy: 0.1110WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/summary_ops_v2.py:1277: stop (from tensorflow.python.eager.profiler) is deprecated and will be removed after 2020-07-01.
# Instructions for updating:
# use `tf.profiler.experimental.stop` instead.
# 20/20 [==============================] - ETA: 0s - loss: 6.2450 - accuracy: 0.5536
# Epoch: 0, accuracy:0.5536,  loss:6.2450,  val_accuracy:0.8401,  val_loss:0.5011,
# 20/20 [==============================] - 86s 4s/step - loss: 6.2450 - accuracy: 0.5536 - val_loss: 0.5011 - val_accuracy: 0.8401
# Epoch 2/10000
# 20/20 [==============================] - 90s 5s/step - loss: 0.3567 - accuracy: 0.8943 - val_loss: 0.2136 - val_accuracy: 0.9342
# Epoch 3/10000
# 20/20 [==============================] - 83s 4s/step - loss: 0.1871 - accuracy: 0.9450 - val_loss: 0.1387 - val_accuracy: 0.9596
# Epoch 4/10000
# 20/20 [==============================] - 86s 4s/step - loss: 0.1272 - accuracy: 0.9622 - val_loss: 0.1106 - val_accuracy: 0.9648
# Epoch 5/10000
# 20/20 [==============================] - 84s 4s/step - loss: 0.0969 - accuracy: 0.9703 - val_loss: 0.0893 - val_accuracy: 0.9714
# Epoch 6/10000
# 20/20 [==============================] - 83s 4s/step - loss: 0.0763 - accuracy: 0.9768 - val_loss: 0.0770 - val_accuracy: 0.9760
# Epoch 7/10000
# 20/20 [==============================] - 82s 4s/step - loss: 0.0617 - accuracy: 0.9810 - val_loss: 0.0721 - val_accuracy: 0.9765
# Epoch 8/10000
# 20/20 [==============================] - 84s 4s/step - loss: 0.0516 - accuracy: 0.9841 - val_loss: 0.0665 - val_accuracy: 0.9791
# Epoch 9/10000
# 20/20 [==============================] - 85s 4s/step - loss: 0.0431 - accuracy: 0.9872 - val_loss: 0.0633 - val_accuracy: 0.9796
# Epoch 10/10000
# 20/20 [==============================] - 87s 4s/step - loss: 0.0370 - accuracy: 0.9891 - val_loss: 0.0640 - val_accuracy: 0.9790
# Epoch 11/10000
# 20/20 [==============================] - 89s 4s/step - loss: 0.0313 - accuracy: 0.9913 - val_loss: 0.0590 - val_accuracy: 0.9804
# Epoch 12/10000
# 20/20 [==============================] - 87s 4s/step - loss: 0.0267 - accuracy: 0.9925 - val_loss: 0.0552 - val_accuracy: 0.9824
# Epoch 13/10000
# 20/20 [==============================] - 89s 4s/step - loss: 0.0237 - accuracy: 0.9935 - val_loss: 0.0590 - val_accuracy: 0.9814
# Epoch 14/10000
# 20/20 [==============================] - 85s 4s/step - loss: 0.0202 - accuracy: 0.9947 - val_loss: 0.0588 - val_accuracy: 0.9827
# Epoch 15/10000
# 20/20 [==============================] - 82s 4s/step - loss: 0.0174 - accuracy: 0.9958 - val_loss: 0.0567 - val_accuracy: 0.9826
# Epoch 16/10000
# 20/20 [==============================] - 81s 4s/step - loss: 0.0164 - accuracy: 0.9954 - val_loss: 0.0647 - val_accuracy: 0.9807
# Epoch 17/10000
# 20/20 [==============================] - 81s 4s/step - loss: 0.0140 - accuracy: 0.9966 - val_loss: 0.0599 - val_accuracy: 0.9829
# Epoch 18/10000
# 20/20 [==============================] - 84s 4s/step - loss: 0.0112 - accuracy: 0.9975 - val_loss: 0.0585 - val_accuracy: 0.9824
# Epoch 19/10000
# 20/20 [==============================] - 90s 4s/step - loss: 0.0091 - accuracy: 0.9982 - val_loss: 0.0600 - val_accuracy: 0.9832
# Epoch 20/10000
# 20/20 [==============================] - 89s 4s/step - loss: 0.0082 - accuracy: 0.9986 - val_loss: 0.0611 - val_accuracy: 0.9830
# Epoch 21/10000
# 20/20 [==============================] - 91s 5s/step - loss: 0.0069 - accuracy: 0.9989 - val_loss: 0.0627 - val_accuracy: 0.9824
# Epoch 22/10000
# 20/20 [==============================] - 90s 4s/step - loss: 0.0061 - accuracy: 0.9992 - val_loss: 0.0617 - val_accuracy: 0.9835
# Epoch 23/10000
# 20/20 [==============================] - 87s 4s/step - loss: 0.0050 - accuracy: 0.9995 - val_loss: 0.0625 - val_accuracy: 0.9829
# Epoch 24/10000
# 20/20 [==============================] - 83s 4s/step - loss: 0.0044 - accuracy: 0.9997 - val_loss: 0.0639 - val_accuracy: 0.9835
# Epoch 25/10000
# 20/20 [==============================] - 83s 4s/step - loss: 0.0038 - accuracy: 0.9997 - val_loss: 0.0623 - val_accuracy: 0.9831
# Epoch 26/10000
# 20/20 [==============================] - 85s 4s/step - loss: 0.0033 - accuracy: 0.9998 - val_loss: 0.0633 - val_accuracy: 0.9838
# Epoch 27/10000
# 20/20 [==============================] - 85s 4s/step - loss: 0.0029 - accuracy: 0.9999 - val_loss: 0.0637 - val_accuracy: 0.9827
# Epoch 28/10000
# 20/20 [==============================] - 90s 5s/step - loss: 0.0025 - accuracy: 0.9999 - val_loss: 0.0645 - val_accuracy: 0.9843
# Epoch 29/10000
# 20/20 [==============================] - 82s 4s/step - loss: 0.0022 - accuracy: 0.9999 - val_loss: 0.0645 - val_accuracy: 0.9840
# Epoch 30/10000
# 20/20 [==============================] - 85s 4s/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0651 - val_accuracy: 0.9842
# Epoch 31/10000
# 20/20 [==============================] - 86s 4s/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0665 - val_accuracy: 0.9837
# Epoch 32/10000
# 20/20 [==============================] - 89s 4s/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 0.9845
# Epoch 33/10000
# 20/20 [==============================] - 83s 4s/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0663 - val_accuracy: 0.9840
# Epoch 34/10000
# 20/20 [==============================] - 81s 4s/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0676 - val_accuracy: 0.9842
# Epoch 35/10000
# 20/20 [==============================] - 80s 4s/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0666 - val_accuracy: 0.9841
# Epoch 36/10000
# 20/20 [==============================] - 84s 4s/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0675 - val_accuracy: 0.9843
# Epoch 37/10000
# 20/20 [==============================] - 86s 4s/step - loss: 9.7143e-04 - accuracy: 1.0000 - val_loss: 0.0680 - val_accuracy: 0.9841
# Epoch 38/10000
# 20/20 [==============================] - 85s 4s/step - loss: 9.0775e-04 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9846
# Epoch 39/10000
# 20/20 [==============================] - 82s 4s/step - loss: 8.6607e-04 - accuracy: 1.0000 - val_loss: 0.0689 - val_accuracy: 0.9848
# Epoch 40/10000
# 20/20 [==============================] - 82s 4s/step - loss: 8.1639e-04 - accuracy: 1.0000 - val_loss: 0.0691 - val_accuracy: 0.9845
# Epoch 41/10000
# 20/20 [==============================] - 81s 4s/step - loss: 7.6385e-04 - accuracy: 1.0000 - val_loss: 0.0698 - val_accuracy: 0.9846
# Epoch 42/10000
# 20/20 [==============================] - 82s 4s/step - loss: 6.9775e-04 - accuracy: 1.0000 - val_loss: 0.0706 - val_accuracy: 0.9845
# Epoch 43/10000
# 20/20 [==============================] - 82s 4s/step - loss: 6.6452e-04 - accuracy: 1.0000 - val_loss: 0.0710 - val_accuracy: 0.9844
# Epoch 44/10000
# 20/20 [==============================] - 84s 4s/step - loss: 6.3298e-04 - accuracy: 1.0000 - val_loss: 0.0720 - val_accuracy: 0.9841
# Epoch 45/10000
# 20/20 [==============================] - 83s 4s/step - loss: 5.8963e-04 - accuracy: 1.0000 - val_loss: 0.0714 - val_accuracy: 0.9845
# Epoch 46/10000
# 20/20 [==============================] - 80s 4s/step - loss: 5.7258e-04 - accuracy: 1.0000 - val_loss: 0.0721 - val_accuracy: 0.9851
# Epoch 47/10000
# 20/20 [==============================] - 80s 4s/step - loss: 5.3032e-04 - accuracy: 1.0000 - val_loss: 0.0719 - val_accuracy: 0.9844
# Epoch 48/10000
# 10/20 [==============>...............] - ETA: 36s - loss: 5.2420e-04 - accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-14ba7798b97b> in <module>()
#       1 regular_model_name = "regular"
#       2 regular_model = getModel(None, regular_model_name)
# ----> 3 histories[regular_model_name] = compile_and_fit(regular_model, regular_model_name)
#
# <ipython-input-12-4bcf590d7409> in compile_and_fit(model, name, optimizer, max_epochs)
#      17     validation_data=(X_test, Y_test),
#      18     callbacks=get_callbacks(name),
# ---> 19     verbose=1
#      20   )
#      21   return history
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#     106   def _method_wrapper(self, *args, **kwargs):
#     107     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# --> 108       return method(self, *args, **kwargs)
#     109
#     110     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1096                 batch_size=batch_size):
#    1097               callbacks.on_train_batch_begin(step)
# -> 1098               tmp_logs = train_function(iterator)
#    1099               if data_handler.should_sync:
#    1100                 context.async_wait()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     778       else:
#     779         compiler = "nonXla"
# --> 780         result = self._call(*args, **kwds)
#     781
#     782       new_tracing_count = self._get_tracing_count()
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     805       # In this case we have created variables on the first call, so we run the
#     806       # defunned version which is guaranteed to never create variables.
# --> 807       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     808     elif self._stateful_fn is not None:
#     809       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2827     with self._lock:
#    2828       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2829     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2830
#    2831   @property
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs, cancellation_manager)
#    1846                            resource_variable_ops.BaseResourceVariable))],
#    1847         captured_inputs=self.captured_inputs,
# -> 1848         cancellation_manager=cancellation_manager)
#    1849
#    1850   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1922       # No tape is watching; skip to running the function.
#    1923       return self._build_call_outputs(self._inference_function.call(
# -> 1924           ctx, args, cancellation_manager=cancellation_manager))
#    1925     forward_backward = self._select_forward_and_backward_functions(
#    1926         args,
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     548               inputs=args,
#     549               attrs=attrs,
# --> 550               ctx=ctx)
#     551         else:
#     552           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ##Training L1 Model

# %%
l1_model_name = "L1"
l1_model = getModel(regularizers.l1(0.001), l1_model_name)
histories[l1_model_name] = compile_and_fit(l1_model, l1_model_name)

# %% [markdown]
# ##Training Group Lasso Model
# Writing a custom regularizer: https://www.tensorflow.org/api_docs/python/tf/keras/regularizers/Regularizer

# %% [markdown]
# ###Writing our custom regularizer

# %%
#writing custom group regularizer
#@tf.keras.utils.register_keras_serializable(package='Custom', name='groupLasso')
class ConvKernelRegularizer(tf.keras.regularizers.Regularizer):
  def __init__(self, l=1e-2):
    self.l = l

  def __call__(self, x):
    if ("conv" not in x.name):
      return
      
    #input is of shape (filter_x, filter_y, no_channels, no_filters)
    
    #coefficient is lambda * sum of squares of x
    term1_coeff = self.l * tf.sqrt(tf.math.reduce_sum(tf.math.square(x)))
    layer_group_sum = 0
    
    #treating each filter as a separate group
    for filter_no in range(x.shape[-1]):
      group = x[:,:,:,filter_no]
      layer_group_sum += tf.sqrt(tf.math.reduce_sum(tf.math.square(group)))
    
    term1 = term1_coeff*layer_group_sum
    return term1

  def get_config(self):
    return {'l': float(self.l)}

# %%
conv_kernel_model_name = "ConvKernel"
conv_kernel_model = getModel(ConvKernelRegularizer(l=1e-2), conv_kernel_model_name)
histories[conv_kernel_model_name] = compile_and_fit(conv_kernel_model, conv_kernel_model_name)

# %% [markdown]
# #Visualizing Distributions of Variables Post-Training

# %%
#Simply viewing the raw distribution of kernel variables
def visualizeDistribution(kernel, title):
  flattened_kernel = kernel.flatten()
  fig, ax = plt.subplots()
  ax.hist(flattened_kernel, bins = int(len(flattened_kernel)/5.))
  ax.set_title(title)

#Looking at the distribution of average of absolute value of groups of each variable
def visualizeConvGroupDistribution(kernel, title):
  group_norms = []
  for filter_no in range(kernel.shape[-1]):
    group = kernel[:,:,:,filter_no]
    group_norm = np.sqrt(np.sum(np.square(group)))
    group_norms.append(group_norm)
  
  fig, ax = plt.subplots()
  ax.hist(group_norms)
  ax.set_title(title)

# %%
#visualizing distributions for all kernels in the model
def visualizeAllDistributions(model):
  counter = 0
  variables = model.variables
  for variable in variables:
    if ("conv" in variable.name and "kernel" in variable.name):
      visualizeDistribution(variable.numpy(), model.name + " Model: Conv Kernel " + str(counter) + " Distribution")
    counter+=1

#visualizing group norm distributions for all kernels in the model
def visualizeAllConvGroupDistributions(model):
  counter = 0
  variables = model.variables
  for variable in variables:
    if ("conv" in variable.name and "kernel" in variable.name):
      visualizeConvGroupDistribution(variable.numpy(), model.name + " Model: Conv Group Kernel " + str(counter) + " Distribution")
    counter+=1

# %% [markdown]
# ##Visualizing Distributions

# %%
visualizeAllDistributions(regular_model)

# %%
visualizeAllDistributions(l1_model)

# %%
visualizeAllDistributions(conv_kernel_model)

# %% [markdown]
# ##Visualizing Group Distributions

# %%
visualizeAllConvGroupDistributions(regular_model)

# %%
visualizeAllGroupDistributions(l1_model)

# %%
visualizeAllConvGroupDistributions(conv_kernel_model)

# %% [markdown]
# ##Counting Zero Parameters and Groups

# %%
def countAllZeroParameters(model, threshold=0.01):
  counter = 0
  variables = model.variables
  print("# parameters close to 0 in " + model.name + " Model: ")
  for variable in variables:
    if ("conv" in variable.name and "kernel" in variable.name):
      variable = variable.numpy()
      totalZeros = np.logical_and(variable<threshold, variable>-threshold).sum()
      print("\tKernel " + str(counter) + ": " + str(totalZeros) + " parameters (" + str(round(totalZeros*100./variable.size, 2)) + "%)")
    counter+=1

def countAllZeroGroups(model, threshold=0.05):
  counter = 0
  variables = model.variables
  print("# groups close to 0 in " + model.name + " Model: ")
  for variable in variables:
    if ("conv" in variable.name and "kernel" in variable.name):
      group_norms = []
      for filter_no in range(variable.shape[-1]):
        group = variable[:,:,:,filter_no]
        group_norm = np.sqrt(np.sum(np.square(group)))
        group_norms.append(group_norm)
      totalZeroGroups = (np.abs(group_norms)<threshold).sum()
      print("\tKernel " + str(counter) + ": " + str(totalZeroGroups) + " groups (" + str(round(totalZeroGroups*100./variable.shape[1], 2)) + "%)")
      counter += 1

# %%
countAllZeroParameters(regular_model)
countAllZeroParameters(l1_model)
countAllZeroParameters(group_lasso_model)

# %%
countAllZeroGroups(regular_model)
countAllZeroGroups(l1_model)
countAllZeroGroups(group_lasso_model)

# %% [markdown]
# #Evaluating performance after removing groups

# %%
def removeZeroGroups(model, threshold=0.01):
    counter = 0
    variables = model.variables
    newVariables = []
    for variable in variables:
      if ("kernel" in variable.name):
        variable_value = variable.numpy()
        group_norms = []
        n_groups = 0
        for filter_no in range(variable.shape[-1]):
          group = variable[:,filter_no]
          group_norm = np.sqrt(np.sum(np.square(group)))
          if (group_norm < threshold):
            n_groups += 1
            variable_value[:,c] = 0
          group_norms.append(group_norm)
        print("Removed " + str(n_groups) + " groups from variable #" + str(counter) + " (" + str(round(n_groups*100./variable.shape[1], 2)) + "% of total)")
        variable.assign(tf.convert_to_tensor(variable_value))
      counter += 1

# %%
removeZeroGroups(group_lasso_model)
loss, accuracy = group_lasso_model.evaluate(x=X_test, y=Y_test)

# %% [markdown]
# #Visualizing Results with Tensorboard

# %%
plotter = tfdocs.plots.HistoryPlotter(metric = 'loss', smoothing_std=10)
plotter.plot(histories)

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# Open an embedded TensorBoard viewer
# %tensorboard --logdir {logdir}

# %%
tensorboard dev list

# %%
# !tensorboard dev upload --logdir  {logdir} \
  --name "Regularizer experiment with MNIST" \
  --description "Implementing and testing group lasso regularizer" \
  --one_shot
